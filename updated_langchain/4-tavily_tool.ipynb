# %%
import os
from dotenv import load_dotenv
load_dotenv()
os.environ["TAVILY_API_KEY"] = os.getenv("TAVILY_API_KEY")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 import os
#       2 from dotenv import load_dotenv
#       3 load_dotenv()
# ----> 4 os.environ["TRAVILY_API_KEY"] = os.getenv("TRAVILY_API_KEY")
#
# File <frozen os>:684, in _Environ.__setitem__(self, key, value)
#     682 'Could not get source, probably due dynamically evaluated source code.'
#
# File <frozen os>:744, in _createenviron.<locals>.check_str(value)
#     742 'Could not get source, probably due dynamically evaluated source code.'
#
# TypeError: str expected, not NoneType
